# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/User/pandas/jordan_lebron.csv')

# %%
df.groupby('game_m')['orb_m'].mean().plot(color='red')
df.groupby('game_l')['orb_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
df.groupby('game_m')['drb_m'].mean().plot(color='red')
df.groupby('game_l')['drb_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
df.groupby('game_m')['trb_m'].mean().plot(color='red')
df.groupby('game_l')['trb_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
df.groupby('game_m')['ast_m'].mean().plot(color='red')
df.groupby('game_l')['ast_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
df.groupby('game_m')['stl_m'].mean().plot(color='red')
df.groupby('game_l')['stl_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
df.groupby('game_m')['blk_m'].mean().plot(color='red')
df.groupby('game_l')['blk_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
df.groupby('game_m')['tov_m'].mean().plot(color='red')
df.groupby('game_l')['tov_l'].mean().plot(color='blue')
# Out:
# <AxesSubplot:xlabel='game_l'>

# %%
import seaborn as sns 
ax = plt.subplots() 
ax = sns.boxplot(x='team_m', y='pts_m', data=df) 
ax.set_title('The team performance.') 
ax.set_xlabel('Team') 
ax.set_ylabel('Pts')
# Out:
# Text(0, 0.5, 'Pts')

# %%
ax = plt.subplots() 
ax = sns.boxplot(x='team_l', y='pts_l', data=df) 
ax.set_title('The team performance.') 
ax.set_xlabel('Team') 
ax.set_ylabel('Pts')
# Out:
# Text(0, 0.5, 'Pts')

# %%
import numpy as np
from sklearn.linear_model import 
from matplotlib import pyplot as plt

X = np.array(df['pts_l']).reshape(-1,1)
y = df['fg_l']
lr = LinearRegression()
lr.fit(X, y)

w = lr.coef_[0]

plt.scatter(X, y, s=1)
plt.plot(X, w*X, c='red')

# %%
X = np.array(df['pts_m']).reshape(-1,1)
y = df['fg_m']
lr = LinearRegression()
lr.fit(X, y)

w = lr.coef_[0]

plt.scatter(X, y, s=1)
plt.plot(X, w*X, c='red')

# %%
X = np.array(df['pts_l']).reshape(-1,1)
y = df['three_l']
lr = LinearRegression()
lr.fit(X, y)

w = lr.coef_[0]

plt.scatter(X, y, s=1)
plt.plot(X, w*X, c='red')

# %%
X = np.array(df['pts_m']).reshape(-1,1)
y = df['three_m']
lr = LinearRegression()
lr.fit(X, y)

w = lr.coef_[0]

plt.scatter(X, y, s=1)
plt.plot(X, w*X, c='red')

# %%
X = np.array(df['pts_l']).reshape(-1,1)
y = df['ft_l']
lr = LinearRegression()
lr.fit(X, y)

w = lr.coef_[0]

plt.scatter(X, y, s=1)
plt.plot(X, w*X, c='red')

# %%
X = np.array(df['pts_m']).reshape(-1,1)
y = df['ft_m']
lr = LinearRegression()
lr.fit(X, y)

w = lr.coef_[0]

plt.scatter(X, y, s=1)
plt.plot(X, w*X, c='red')
